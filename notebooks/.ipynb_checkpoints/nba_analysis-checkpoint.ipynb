# %% [markdown]
# ## 1. Data Loading
# Load NBA datasets and inspect structure.

# %%
import pandas as pd

# Load datasets (update filenames based on what you downloaded)
games = pd.read_csv("../data/raw/games.csv")
teams = pd.read_csv("../data/raw/teams.csv")

# Preview data
print(games.head())
print(games.shape)
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      46.0    1610612759     117.0        0.478        0.815         0.321
# 1      40.0    1610612764     112.0        0.561        0.765         0.333
# 2      37.0    1610612749     106.0        0.470        0.682         0.433
# 3      49.0    1610612765      93.0        0.392        0.735         0.261
# 4      47.0    1610612741     110.0        0.500        0.773         0.292
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      23.0      44.0               1
# 1      20.0      37.0               1
# 2      20.0      46.0               1
# 3      15.0      46.0               1
# 4      20.0      47.0               0
#
# [5 rows x 21 columns]
# (26651, 21)

# %% [markdown]
# ## 2. Data cleaning
# Handle missing values, fix data types, and prepare dataset.

# %%
# Check missing values
print(games.isnull().sum())

# Drop rows with missing scores (important)
games = games.dropna(subset=["PTS_home", "PTS_away"])

# Convert date column (if exists)
if "game_date" in games.columns:
    games["game_date"] = pd.to_datetime(games["game_date"])

# Create target variable (HomeWin)
games["home_win"] = (games["PTS_home"] > games["PTS_away"]).astype(int)

# Check result
print(games[["home_team_score", "visitor_team_score", "home_win"]].head())
# Out:
# GAME_DATE_EST        0
# GAME_ID              0
# GAME_STATUS_TEXT     0
# HOME_TEAM_ID         0
# VISITOR_TEAM_ID      0
# SEASON               0
# TEAM_ID_home         0
# PTS_home            99
# FG_PCT_home         99
# FT_PCT_home         99
# FG3_PCT_home        99
# AST_home            99
# REB_home            99
# TEAM_ID_away         0
# PTS_away            99
# FG_PCT_away         99
# FT_PCT_away         99
# FG3_PCT_away        99
# AST_away            99
# REB_away            99
# HOME_TEAM_WINS       0
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/4v/g1c5989x7nn265x_6grqqz9m0000gp/T/ipykernel_37058/819701187.py in ?()
# ----> 5 # Check missing values
#       6 print(games.isnull().sum())
#       7
#       8 # Drop rows with missing scores (important)
#
# ~/Documents/GitHub/NBA_game_predictor/venv/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6688             ax = self._get_axis(agg_axis)
#    6689             indices = ax.get_indexer_for(subset)
#    6690             check = indices == -1
#    6691             if check.any():
# -> 6692                 raise KeyError(np.array(subset)[check].tolist())
#    6693             agg_obj = self.take(indices, axis=agg_axis)
#    6694
#    6695         if thresh is not lib.no_default:
#
# KeyError: ['home_team_score', 'visitor_team_score']

# %%
print(games.columns.tolist())
# Out:
# ['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away', 'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away', 'HOME_TEAM_WINS']

# %% [markdown]
# ## 3. Feature Engineering
# Create features for model training.

# %%
# Example: score difference (you can add more later)
games["score_diff"] = games["home_team_score"] - games["visitor_team_score"]

# Keep only useful columns for now
model_data = games[["score_diff", "home_win"]]

print(model_data.head())

# %% [markdown]
# ## 4: EDA
# Visualize patterns and relationships in the data.

# %%
import matplotlib.pyplot as plt

# %%
games["home_win"].value_counts().plot(kind="bar")
plt.title("Home vs Away Wins")
plt.xlabel("Home Win (1 = Yes, 0 = No)")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(games["score_diff"], bins=30)
plt.title("Score Difference Distribution")
plt.xlabel("Score Difference")
plt.ylabel("Frequency")
plt.show()

# %%
print(games[["score_diff", "home_win"]].corr())

# %% [markdown]
# ## Insights
#
# - Home teams appear to win more frequently than away teams.
# - Larger score differences strongly indicate a higher likelihood of winning.
# - The dataset shows a clear relationship between performance metrics and outcomes.
